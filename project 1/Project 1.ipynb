# %% [markdown]
# **IMPORTING FILE**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
fs = files.upload()
# Out:
#      <input type="file" id="files-01122d67-9639-416e-8026-9c831efe1ed5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-01122d67-9639-416e-8026-9c831efe1ed5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('BKB_WaterQualityData_2020084 (2).csv')

# %%
df
# Out:
#      Site_Id Unit_Id   Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0        Bay     NaN    1/3/1994             1.3                     11.7
# 1        Bay     NaN   1/31/1994             1.5                     12.0
# 2        Bay     NaN    2/7/1994             1.0                     10.5
# 3        Bay     NaN   2/23/1994             1.0                     10.1
# 4        Bay     NaN   2/28/1994             1.0                     12.6
# ...      ...     ...         ...             ...                      ...
# 2366     Bay     NaN  10/11/2018             1.9                      5.0
# 2367     Bay     NaN  10/24/2018             0.0                      9.0
# 2368     Bay     NaN  10/28/2018             0.9                      2.9
# 2369     Bay     NaN   11/7/2018             1.7                      NaN
# 2370     Bay     NaN  12/11/2018             0.1                      NaN
#
#       pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# ...

# %%
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()
df4 = df.copy()
df5 = df.copy()

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %%
df1.shape
# Out:
# (2371, 17)

# %%
df1.head()
# Out:
#   Site_Id Unit_Id  Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0     Bay     NaN   1/3/1994             1.3                     11.7
# 1     Bay     NaN  1/31/1994             1.5                     12.0
# 2     Bay     NaN   2/7/1994             1.0                     10.5
# 3     Bay     NaN  2/23/1994             1.0                     10.1
# 4     Bay     NaN  2/28/1994             1.0                     12.6
#
#    pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# 0                  7.3              0.40             0.40              5.9
# 1                  7.4              0.20             0.35              3.0
# 2                  7.2              0.25             0.60              5.9
# 3                  7.4              0.35             0.50             10.0
# 4                  7.2              0.20             0.40              1.6
#
#    Air Temp-Celsius  Air Temp (?F) Time (24:00) Field_Tech DateVerified  \
# ...

# %%
df1.tail()
# Out:
#      Site_Id Unit_Id   Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 2366     Bay     NaN  10/11/2018             1.9                      5.0
# 2367     Bay     NaN  10/24/2018             0.0                      9.0
# 2368     Bay     NaN  10/28/2018             0.9                      2.9
# 2369     Bay     NaN   11/7/2018             1.7                      NaN
# 2370     Bay     NaN  12/11/2018             0.1                      NaN
#
#       pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# 2366                  7.0              4.00              1.2             25.0
# 2367                  7.0              0.30              0.6             18.0
# 2368                  7.0              0.40              0.9             13.0
# 2369                  7.0              0.45              0.9             20.0
# 2370                  7.0              0.10              0.1             10.0
#
# ...

# %%
df1.iloc[100:200]
# Out:
#     Site_Id Unit_Id  Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 100     Bay     NaN   3/4/1991             1.2                    10.00
# 101     Bay     NaN  3/11/1991             0.4                    12.90
# 102     Bay     NaN  3/18/1991             NaN                     9.95
# 103     Bay     NaN  3/25/1991             0.0                     9.80
# 104     Bay     NaN   4/4/1991             1.2                    10.70
# ..      ...     ...        ...             ...                      ...
# 195     Bay     NaN  4/26/1993             3.4                     8.70
# 196     Bay     NaN  5/10/1993             3.2                     8.00
# 197     Bay     NaN  5/17/1993             3.9                     8.00
# 198     Bay     NaN  5/24/1993             2.9                     9.00
# 199     Bay     NaN   6/7/1993             3.7                      NaN
#
#      pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2371 entries, 0 to 2370
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Site_Id                  2370 non-null   object
#  1   Unit_Id                  32 non-null     object
#  2   Read_Date                2366 non-null   object
#  3   Salinity (ppt)           2241 non-null   float64
#  4   Dissolved Oxygen (mg/L)  1520 non-null   float64
#  5   pH (standard units)      2276 non-null   float64
#  6   Secchi Depth (m)         2298 non-null   float64
#  7   Water Depth (m)          2300 non-null   float64
#  8   Water Temp (?C)          2250 non-null   float64
#  9   Air Temp-Celsius         85 non-null     float64
#  10  Air Temp (?F)            2300 non-null   float64
#  11  Time (24:00)             2308 non-null   object
#  12  Field_Tech               2332 non-null   object
#  13  DateVerified             453 non-null    object
# ...

# %%
df1.columns
# Out:
# Index(['Site_Id', 'Unit_Id', 'Read_Date', 'Salinity (ppt)',
#        'Dissolved Oxygen (mg/L)', 'pH (standard units)', 'Secchi Depth (m)',
#        'Water Depth (m)', 'Water Temp (?C)', 'Air Temp-Celsius',
#        'Air Temp (?F)', 'Time (24:00)', 'Field_Tech', 'DateVerified',
#        'WhoVerified', 'AirTemp (C)', 'Year'],
#       dtype='object')

# %%
df1.describe()
# Out:
#        Salinity (ppt)  Dissolved Oxygen (mg/L)  pH (standard units)  \
# count     2241.000000              1520.000000          2276.000000
# mean         0.717068                 6.646263             7.168212
# std          1.230819                 2.506608             0.788485
# min          0.000000                 0.000000             0.300000
# 25%          0.000000                 4.800000             6.500000
# 50%          0.000000                 6.500000             7.000000
# 75%          1.000000                 8.500000             7.500000
# max          9.000000                15.100000             9.900000
#
#        Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  Air Temp-Celsius  \
# count       2298.000000      2300.000000      2250.000000         85.000000
# mean           0.524898         0.762559        18.062138         16.437647
# std            0.473663         0.621140         8.298246         11.754138
# ...

# %% [markdown]
# **DIAGRAM REPRESENTATION**

# %%
summary1 = df1.describe()

# %%
summary1.T.plot(kind='bar', figsize=(10,5))
plt.title('Summary1 Statistics')
plt.ylabel('Values')
plt.xlabel('Statistics')
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# **DATACLEANING**

# %%
df1.isna()
# Out:
#       Site_Id  Unit_Id  Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0       False     True      False           False                    False
# 1       False     True      False           False                    False
# 2       False     True      False           False                    False
# 3       False     True      False           False                    False
# 4       False     True      False           False                    False
# ...       ...      ...        ...             ...                      ...
# 2366    False     True      False           False                    False
# 2367    False     True      False           False                    False
# 2368    False     True      False           False                    False
# 2369    False     True      False           False                     True
# 2370    False     True      False           False                     True
#
# ...

# %%
df1 = df1.drop(['Site_Id'],axis = 1)

# %%
df1 = df1.drop(['Unit_Id'],axis = 1)

# %%
df1 = df1.drop(['Read_Date'],axis = 1)

# %%
df1.isna().sum()
# Out:
# Salinity (ppt)              130
# Dissolved Oxygen (mg/L)     851
# pH (standard units)          95
# Secchi Depth (m)             73
# Water Depth (m)              71
# Water Temp (?C)             121
# Air Temp-Celsius           2286
# Air Temp (?F)                71
# Time (24:00)                 63
# Field_Tech                   39
# DateVerified               1918
# WhoVerified                1918
# AirTemp (C)                   0
# Year                          0
# dtype: int64

# %% [markdown]
# ## Total no of records = 2371
# Salinity = 130/2371*100 =5.4
#
# Dissolved Oxygen (mg/L) = 851/2371*100 = 35.89
#
# Secchi Depth (m) = 73/2371*100 = 3.07
#
# Water Depth (m)= 71/2371*100 = 2.9
#
# Water Temp (?C) =121/2371*100 =5.1
#
# Air Temp-Celsius = 2286/2371*100 =96.4
#
# Air Temp (?F) = 71/2371*100 =2.9
#
# Time (24:00) = 63/2371*100 =2.6
#
# Field_Tech = 39/2371*100 =1.6
#
# DateVerified = 1918/2371*100 =80.89
#
# WhoVerified = 1918/2371*100 =80.89
#
# pH (standard units) = 95/2371*100 = 4
#
#
#
# MORE THAN 3% MISSING VALUE SO WE HAVE TO DEAL

# %% [markdown]
# DROPPING THE COLUMN WHICH HAVE LESS THAN 3% AND MORE THAN 60% MISSING VALUES

# %%
df1 = df1.drop(['Water Depth (m)'],axis =1)

# %%
df1 = df1.drop(['Air Temp (?F)'],axis =1)

# %%
df1 = df1.drop(['Time (24:00)'],axis =1)

# %%
df1 = df1.drop(['DateVerified'],axis =1)

# %%
df1 = df1.drop(['WhoVerified'],axis =1)

# %%
df1 = df1.drop(['Field_Tech'],axis =1)

# %%
df1 = df1.drop(['Air Temp-Celsius'],axis =1)

# %%
flo_cols = ['Salinity (ppt)','Dissolved Oxygen (mg/L)','Secchi Depth (m)','Water Temp (?C)']

# %%
df1[flo_cols] = df1[flo_cols].fillna(df1.mode().iloc[0])

# %%
 df1 = df1.dropna(subset = ['pH (standard units)'])

# %%
df1.isna().sum()
# Out:
# Salinity (ppt)             0
# Dissolved Oxygen (mg/L)    0
# pH (standard units)        0
# Secchi Depth (m)           0
# Water Temp (?C)            0
# AirTemp (C)                0
# Year                       0
# dtype: int64

# %% [markdown]
# #  LABEL ENCODING

# %% [markdown]
# NO CATEGORICAL COLUMNS
#
# HENCE ENCODING NOT NEEDED

# %% [markdown]
# #SPLITING x1 AND y1

# %%
x1 = df1.iloc[:,[0,1,3,4,5,6]]

# %%
x1
# Out:
#       Salinity (ppt)  Dissolved Oxygen (mg/L)  Secchi Depth (m)  \
# 0                1.3                     11.7              0.40
# 1                1.5                     12.0              0.20
# 2                1.0                     10.5              0.25
# 3                1.0                     10.1              0.35
# 4                1.0                     12.6              0.20
# ...              ...                      ...               ...
# 2366             1.9                      5.0              4.00
# 2367             0.0                      9.0              0.30
# 2368             0.9                      2.9              0.40
# 2369             1.7                     10.0              0.45
# 2370             0.1                     10.0              0.10
#
#       Water Temp (?C)  AirTemp (C)  Year
# 0                 5.9     8.000000  1994
# 1                 3.0     2.600000  1994
# 2                 5.9     7.600000  1994
# ...

# %%
y1 = df1.iloc[:,2]

# %%
y1
# Out:
# 0       7.3
# 1       7.4
# 2       7.2
# 3       7.4
# 4       7.2
#        ...
# 2366    7.0
# 2367    7.0
# 2368    7.0
# 2369    7.0
# 2370    7.0
# Name: pH (standard units), Length: 2276, dtype: float64

# %% [markdown]
# **TRAIN** **TEST** **SPLIT**

# %%
from sklearn.model_selection import train_test_split
x1_train,x1_test,y1_train,y1_test = train_test_split(x1,y1,test_size=0.3,random_state = 5)

# %%
x1_train
# Out:
#       Salinity (ppt)  Dissolved Oxygen (mg/L)  Secchi Depth (m)  \
# 2152             0.0                     10.0              0.40
# 215              1.8                     10.6              0.40
# 1335             2.0                     10.0              0.25
# 1626             0.0                      3.9              0.40
# 1170             0.0                     10.0              0.70
# ...              ...                      ...               ...
# 1072             0.0                      8.5              0.20
# 2209             0.0                     10.0              1.00
# 1480             0.0                     10.0              0.70
# 1795             0.0                      5.3              0.40
# 2349             0.0                      6.3              0.40
#
#       Water Temp (?C)  AirTemp (C)  Year
# 2152             19.0    16.111111  2017
# 215              15.6    18.900000  1993
# 1335             27.0   -17.777778  2008
# ...

# %%
x1_test
# Out:
#       Salinity (ppt)  Dissolved Oxygen (mg/L)  Secchi Depth (m)  \
# 1599             0.0                     10.0             1.200
# 517              2.0                     10.0             0.500
# 990              0.0                     10.0             0.600
# 2313             0.0                      4.5             0.400
# 1176             0.0                      3.7             0.500
# ...              ...                      ...               ...
# 151              4.2                      9.2             0.300
# 2091             0.0                      3.9             0.400
# 2286             0.0                      4.1             0.300
# 112              3.8                      6.8             0.325
# 1038             0.0                      5.0             0.100
#
#       Water Temp (?C)  AirTemp (C)  Year
# 1599             27.0    16.111111  2010
# 517              21.0    22.777778  2001
# 990              32.0   -17.777778  2005
# ...

# %%
y1_train
# Out:
# 2152    6.5
# 215     8.4
# 1335    8.5
# 1626    6.5
# 1170    7.0
#        ...
# 1072    7.0
# 2209    6.5
# 1480    6.5
# 1795    8.0
# 2349    9.0
# Name: pH (standard units), Length: 1593, dtype: float64

# %%
y1_test
# Out:
# 1599    6.0
# 517     7.8
# 990     6.5
# 2313    9.0
# 1176    7.0
#        ...
# 151     7.5
# 2091    7.5
# 2286    7.0
# 112     7.5
# 1038    6.5
# Name: pH (standard units), Length: 683, dtype: float64

# %% [markdown]
# **MODEL BUILDING**

# %%
#REGRESSION
from sklearn.linear_model import LinearRegression
model1 = LinearRegression()
model1.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
y1_predict = model1.predict(x1_test)

# %% [markdown]
# **EVALUATION REGRESSION**

# %%
from sklearn.metrics import mean_absolute_error

# %%
print("MAE 1 is ",mean_absolute_error(y1_test,y1_predict))
# Out:
# MAE 1 is  0.5443304142515795

# %%
from sklearn.metrics import mean_squared_error

# %%
print("MSE 1 is",mean_squared_error(y1_test,y1_predict))
# Out:
# MSE 1 is 0.5827638762364757

# %%
from sklearn.metrics import root_mean_squared_error

# %%
print("RMSE 1 is ",root_mean_squared_error(y1_test,y1_predict))
# Out:
# RMSE 1 is  0.7633897276204833

# %% [markdown]
# # REPRESENTATION OF MAE1,MSE1,RMSE1

# %%
MAE1 = 0.5443
MSE1 = 0.5827
RMSE1= 0.7633

# %%
metrics = ['MAE1', 'MSE1', 'RMSE1']
values = [MAE1, MSE1, RMSE1]

# %%
plt.bar(metrics, values)
plt.xlabel('Metrics')
plt.ylabel('Error Values')
plt.title('Error Metrics for Model 1')
# Out:
# Text(0.5, 1.0, 'Error Metrics for Model 1')

# %% [markdown]
# # MODEL 1 CONCLUSION
#
# ***Model 1 represents the baseline model analysis, incorporating data cleaning steps such as dropping irrelevant columns and handling missing values through imputation***.

# %% [markdown]
# #**df2**

# %%
df2
# Out:
#      Site_Id Unit_Id   Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0        Bay     NaN    1/3/1994             1.3                     11.7
# 1        Bay     NaN   1/31/1994             1.5                     12.0
# 2        Bay     NaN    2/7/1994             1.0                     10.5
# 3        Bay     NaN   2/23/1994             1.0                     10.1
# 4        Bay     NaN   2/28/1994             1.0                     12.6
# ...      ...     ...         ...             ...                      ...
# 2366     Bay     NaN  10/11/2018             1.9                      5.0
# 2367     Bay     NaN  10/24/2018             0.0                      9.0
# 2368     Bay     NaN  10/28/2018             0.9                      2.9
# 2369     Bay     NaN   11/7/2018             1.7                      NaN
# 2370     Bay     NaN  12/11/2018             0.1                      NaN
#
#       pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# ...

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %%
df2.shape
# Out:
# (2371, 17)

# %%
df2.head()
# Out:
#   Site_Id Unit_Id  Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0     Bay     NaN   1/3/1994             1.3                     11.7
# 1     Bay     NaN  1/31/1994             1.5                     12.0
# 2     Bay     NaN   2/7/1994             1.0                     10.5
# 3     Bay     NaN  2/23/1994             1.0                     10.1
# 4     Bay     NaN  2/28/1994             1.0                     12.6
#
#    pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# 0                  7.3              0.40             0.40              5.9
# 1                  7.4              0.20             0.35              3.0
# 2                  7.2              0.25             0.60              5.9
# 3                  7.4              0.35             0.50             10.0
# 4                  7.2              0.20             0.40              1.6
#
#    Air Temp-Celsius  Air Temp (?F) Time (24:00) Field_Tech DateVerified  \
# ...

# %%
df2.tail()
# Out:
#      Site_Id Unit_Id   Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 2366     Bay     NaN  10/11/2018             1.9                      5.0
# 2367     Bay     NaN  10/24/2018             0.0                      9.0
# 2368     Bay     NaN  10/28/2018             0.9                      2.9
# 2369     Bay     NaN   11/7/2018             1.7                      NaN
# 2370     Bay     NaN  12/11/2018             0.1                      NaN
#
#       pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# 2366                  7.0              4.00              1.2             25.0
# 2367                  7.0              0.30              0.6             18.0
# 2368                  7.0              0.40              0.9             13.0
# 2369                  7.0              0.45              0.9             20.0
# 2370                  7.0              0.10              0.1             10.0
#
# ...

# %%
df2.iloc[200:400]
# Out:
#     Site_Id Unit_Id  Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 200     Bay     NaN  6/14/1993             3.9                      8.1
# 201     Bay     NaN  6/21/1993             3.8                      7.2
# 202     Bay     NaN  6/28/1993             3.9                      7.1
# 203     Bay     NaN   7/5/1993             NaN                      7.4
# 204     Bay     NaN  7/19/1993             4.2                      7.3
# ..      ...     ...        ...             ...                      ...
# 395       A     NaN  5/15/2000             1.0                      6.4
# 396       A     NaN  5/30/2000             0.5                      NaN
# 397       A     NaN  6/13/2000             1.0                      NaN
# 398       A     NaN  6/26/2000             1.0                      5.5
# 399       A     NaN  7/11/2000             0.8                      NaN
#
#      pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2371 entries, 0 to 2370
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Site_Id                  2370 non-null   object
#  1   Unit_Id                  32 non-null     object
#  2   Read_Date                2366 non-null   object
#  3   Salinity (ppt)           2241 non-null   float64
#  4   Dissolved Oxygen (mg/L)  1520 non-null   float64
#  5   pH (standard units)      2276 non-null   float64
#  6   Secchi Depth (m)         2298 non-null   float64
#  7   Water Depth (m)          2300 non-null   float64
#  8   Water Temp (?C)          2250 non-null   float64
#  9   Air Temp-Celsius         85 non-null     float64
#  10  Air Temp (?F)            2300 non-null   float64
#  11  Time (24:00)             2308 non-null   object
#  12  Field_Tech               2332 non-null   object
#  13  DateVerified             453 non-null    object
# ...

# %%
df2.columns
# Out:
# Index(['Site_Id', 'Unit_Id', 'Read_Date', 'Salinity (ppt)',
#        'Dissolved Oxygen (mg/L)', 'pH (standard units)', 'Secchi Depth (m)',
#        'Water Depth (m)', 'Water Temp (?C)', 'Air Temp-Celsius',
#        'Air Temp (?F)', 'Time (24:00)', 'Field_Tech', 'DateVerified',
#        'WhoVerified', 'AirTemp (C)', 'Year'],
#       dtype='object')

# %%
df2.describe()
# Out:
#        Salinity (ppt)  Dissolved Oxygen (mg/L)  pH (standard units)  \
# count     2241.000000              1520.000000          2276.000000
# mean         0.717068                 6.646263             7.168212
# std          1.230819                 2.506608             0.788485
# min          0.000000                 0.000000             0.300000
# 25%          0.000000                 4.800000             6.500000
# 50%          0.000000                 6.500000             7.000000
# 75%          1.000000                 8.500000             7.500000
# max          9.000000                15.100000             9.900000
#
#        Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  Air Temp-Celsius  \
# count       2298.000000      2300.000000      2250.000000         85.000000
# mean           0.524898         0.762559        18.062138         16.437647
# std            0.473663         0.621140         8.298246         11.754138
# ...

# %% [markdown]
# #**GRAPH** **REPRESENTATION**

# %%
summary2 = df2.describe()

# %%
summary2.T.plot(kind='bar', figsize=(10,5))
plt.title('Summary2 Statistics')
plt.ylabel('Values')
plt.xlabel('Statistics')
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# #**DATACLEANING**

# %%
df2.isna()
# Out:
#       Site_Id  Unit_Id  Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0       False     True      False           False                    False
# 1       False     True      False           False                    False
# 2       False     True      False           False                    False
# 3       False     True      False           False                    False
# 4       False     True      False           False                    False
# ...       ...      ...        ...             ...                      ...
# 2366    False     True      False           False                    False
# 2367    False     True      False           False                    False
# 2368    False     True      False           False                    False
# 2369    False     True      False           False                     True
# 2370    False     True      False           False                     True
#
# ...

# %%
df2.isna().sum()
# Out:
# Site_Id                       1
# Unit_Id                    2339
# Read_Date                     5
# Salinity (ppt)              130
# Dissolved Oxygen (mg/L)     851
# pH (standard units)          95
# Secchi Depth (m)             73
# Water Depth (m)              71
# Water Temp (?C)             121
# Air Temp-Celsius           2286
# Air Temp (?F)                71
# Time (24:00)                 63
# Field_Tech                   39
# DateVerified               1918
# WhoVerified                1918
# AirTemp (C)                   0
# Year                          0
# dtype: int64

# %%
df2 = df2.drop(['Site_Id'],axis = 1)

# %%
df2 = df2.drop(['Unit_Id'],axis = 1)

# %%
df2 = df2.drop(['Read_Date'],axis = 1)

# %%
df2.isna().sum()
# Out:
# Salinity (ppt)              130
# Dissolved Oxygen (mg/L)     851
# pH (standard units)          95
# Secchi Depth (m)             73
# Water Depth (m)              71
# Water Temp (?C)             121
# Air Temp-Celsius           2286
# Air Temp (?F)                71
# Time (24:00)                 63
# Field_Tech                   39
# DateVerified               1918
# WhoVerified                1918
# AirTemp (C)                   0
# Year                          0
# dtype: int64

# %% [markdown]
# # Total no of records = 2371
# Salinity = 130/2371*100 =5.4
#
# Dissolved Oxygen (mg/L) = 851/2371*100 = 35.89
#
# Secchi Depth (m) = 73/2371*100 = 3.07
#
# Water Depth (m)= 71/2371*100 = 2.9
#
# Water Temp (?C) =121/2371*100 =5.1
#
# Air Temp-Celsius = 2286/2371*100 =96.4
#
# Air Temp (?F) = 71/2371*100 =2.9
#
# Time (24:00) = 63/2371*100 =2.6
#
# Field_Tech = 39/2371*100 =1.6
#
# DateVerified = 1918/2371*100 =80.89
#
# WhoVerified = 1918/2371*100 =80.89
#
# pH (standard units) = 95/2371*100 = 4
#
#
# MORE THAN 3% MISSING VALUES SO WE HAVE TO DEAL

# %% [markdown]
# DROPPING COLUMNS WHICH HAVE LESS THAN 3% AND MORE THAN 60% MISSING VALUES

# %%
df2 = df2.drop(['Water Depth (m)'],axis = 1)

# %%
df2 = df2.drop(['Air Temp (?F)'],axis = 1)

# %%
df2 = df2.drop(['Time (24:00)'],axis = 1)

# %%
df2 = df2.drop(['Field_Tech'],axis = 1)

# %%
df2 = df2.drop(['Air Temp-Celsius'],axis = 1)

# %%
df2 = df2.drop(['DateVerified'],axis = 1)

# %%
df2 = df2.drop(['WhoVerified'],axis = 1)

# %%
flo_cols = ['Salinity (ppt)','Dissolved Oxygen (mg/L)','Secchi Depth (m)','Water Temp (?C)']

# %%
df2[flo_cols] = df2[flo_cols].fillna(df1.mode().iloc[0])

# %%
df2 = df2.dropna(subset = ['pH (standard units)'])

# %%
df2.isna().sum()
# Out:
# Salinity (ppt)             0
# Dissolved Oxygen (mg/L)    0
# pH (standard units)        0
# Secchi Depth (m)           0
# Water Temp (?C)            0
# AirTemp (C)                0
# Year                       0
# dtype: int64

# %% [markdown]
# #**LABELENCODING**

# %% [markdown]
# NO CATEGORICAL COLUMNS
#
#  HENCE ENCODING NOT NEEDED

# %% [markdown]
# #**OUTLIER** **DETECTION**

# %%
figure = df2.boxplot(column = 'Salinity (ppt)')

# %%
figure = df2.boxplot(column = 'Secchi Depth (m)')

# %%
figure = df2.boxplot(column = 'Water Temp (?C)')

# %%
figure = df2.boxplot(column = 'pH (standard units)')

# %%
figure = df2.boxplot(column = 'AirTemp (C)')

# %%
figure = df2.boxplot(column ='Year')

# %% [markdown]
# CALCULATING IQR AND UPPER_BRIDGE,LOWER_BRIDGE VALUES FOR EACH OUTLIER DETECTED COLUMN

# %%
IQR1 = df2['Salinity (ppt)'].quantile(0.75)-df2['Salinity (ppt)'].quantile(0.25)

# %%
lower_bridge1 = df2['Salinity (ppt)'].quantile(0.25)-(IQR1*1.5)
upper_bridge1 = df2['Salinity (ppt)'].quantile(0.75)+(IQR1*1.5)

# %%
IQR1
# Out:
# 1.0

# %%
IQR2 = df2['Secchi Depth (m)'].quantile(0.75)-df2['Secchi Depth (m)'].quantile(0.25)

# %%
lower_bridge2 = df2['Secchi Depth (m)'].quantile(0.25)-(IQR2*1.5)
upper_bridge2 = df2['Secchi Depth (m)'].quantile(0.75)+(IQR2*1.5)

# %%
IQR2
# Out:
# 0.35000000000000003

# %%
IQR3 = df2['pH (standard units)'].quantile(0.75)-df2['pH (standard units)'].quantile(0.25)

# %%
lower_bridge3 = df2['pH (standard units)'].quantile(0.25)-(IQR3*1.5)
upper_bridge3 = df2['pH (standard units)'].quantile(0.75)+(IQR3*1.5)

# %%
IQR3
# Out:
# 1.0

# %%
IQR4 = df2['Water Temp (?C)'].quantile(0.75)-df2['Water Temp (?C)'].quantile(0.25)

# %%
lower_bridge4 = df2['Water Temp (?C)'].quantile(0.25)-(IQR4*1.5)
upper_bridge4 = df2['Water Temp (?C)'].quantile(0.75)+(IQR4*1.5)

# %%
IQR4
# Out:
# 15.0

# %%
IQR5 = df2['AirTemp (C)'].quantile(0.75)-df2['AirTemp (C)'].quantile(0.25)

# %%
lower_bridge5 = df2['AirTemp (C)'].quantile(0.25)-(IQR5*1.5)
upper_bridge5 = df2['AirTemp (C)'].quantile(0.75)+(IQR5*1.5)

# %%
IQR5
# Out:
# 15.000000001

# %%
IQR6 = df2['Year'].quantile(0.75)-df2['Year'].quantile(0.25)

# %%
lower_bridge6 = df2['Year'].quantile(0.25)-(IQR6*1.5)
upper_bridge6 = df2['Year'].quantile(0.75)+(IQR6*1.5)

# %%
IQR6
# Out:
# 11.0

# %% [markdown]
# **SHAPE** **BEFORE** **OUTLIER** **REMOVAL**

# %%
print('oldshape',df2.shape)
# Out:
# oldshape (2276, 7)

# %% [markdown]
# # **OUTLIER** **REMOVAL**

# %%
df2 = df2[(df2['Salinity (ppt)'] > lower_bridge1) & (df2['Salinity (ppt)'] < upper_bridge1)]

# %%
df2 = df2[(df2['Secchi Depth (m)'] > lower_bridge2) & (df2['Secchi Depth (m)'] < upper_bridge2)]

# %%
df2 = df2[(df2['pH (standard units)']> lower_bridge3) & (df2['pH (standard units)'] < upper_bridge3)]

# %%
df2 = df2[(df2['Water Temp (?C)'] > lower_bridge4) & (df2['Water Temp (?C)'] < upper_bridge4)]

# %%
df2 = df2[(df2['AirTemp (C)'] > lower_bridge5) & (df2['AirTemp (C)'] < upper_bridge5)]

# %%
df2 = df2[(df2['Year'] > lower_bridge6) & (df2['Year'] < upper_bridge6)]

# %% [markdown]
#  **SHAPE** **AFTER** **OUTLIER** **REMOVAL**

# %%
print('newshape',df2.shape)
# Out:
# newshape (1772, 7)

# %% [markdown]
# #**SPLITING** **X2** **AND** **Y2**

# %%
x2 = df2.iloc[:,[0,1,3,4,5,6]]

# %%
x2
# Out:
#       Salinity (ppt)  Dissolved Oxygen (mg/L)  Secchi Depth (m)  \
# 0                1.3                     11.7              0.40
# 1                1.5                     12.0              0.20
# 2                1.0                     10.5              0.25
# 3                1.0                     10.1              0.35
# 4                1.0                     12.6              0.20
# ...              ...                      ...               ...
# 2364             0.0                      6.9              0.90
# 2367             0.0                      9.0              0.30
# 2368             0.9                      2.9              0.40
# 2369             1.7                     10.0              0.45
# 2370             0.1                     10.0              0.10
#
#       Water Temp (?C)  AirTemp (C)  Year
# 0                 5.9     8.000000  1994
# 1                 3.0     2.600000  1994
# 2                 5.9     7.600000  1994
# ...

# %%
y2 = df2.iloc[:,2]

# %%
y2
# Out:
# 0       7.3
# 1       7.4
# 2       7.2
# 3       7.4
# 4       7.2
#        ...
# 2364    6.5
# 2367    7.0
# 2368    7.0
# 2369    7.0
# 2370    7.0
# Name: pH (standard units), Length: 1772, dtype: float64

# %% [markdown]
# #**TRAIN** **TEST** **SPLIT**

# %%
from sklearn.model_selection import train_test_split
x2_train,x2_test,y2_train,y2_test = train_test_split(x2,y2,test_size=0.3,random_state = 5)

# %%
x2_train
# Out:
#       Salinity (ppt)  Dissolved Oxygen (mg/L)  Secchi Depth (m)  \
# 2117             0.0                      7.6              0.40
# 2014             0.0                     10.0              1.00
# 2158             0.0                      4.2              0.20
# 1111             0.0                     10.0              0.10
# 958              0.0                      7.0              0.90
# ...              ...                      ...               ...
# 1648             0.0                      3.6              0.40
# 1478             0.0                     10.0              0.70
# 2321             0.0                     10.0              0.90
# 433              1.0                      5.9              0.65
# 1329             0.0                      5.2              0.60
#
#       Water Temp (?C)  AirTemp (C)  Year
# 2117             11.0     8.888889  2016
# 2014             19.0    18.333333  2015
# 2158             28.0    27.222222  2017
# ...

# %%
x2_test
# Out:
#       Salinity (ppt)  Dissolved Oxygen (mg/L)  Secchi Depth (m)  \
# 1257             0.0                      9.3              0.30
# 1029             0.0                      6.9              0.40
# 1644             0.0                      8.0              0.80
# 1303             0.0                     10.0              0.45
# 848              0.0                      5.4              0.20
# ...              ...                      ...               ...
# 1944             0.0                     10.0              0.60
# 8                1.0                      9.2              0.25
# 448              0.0                     10.0              0.35
# 731              0.0                     10.0              0.40
# 1441             0.0                     10.0              0.48
#
#       Water Temp (?C)  AirTemp (C)  Year
# 1257              3.0    -3.333333  2007
# 1029             15.0    14.444444  2005
# 1644             12.0     8.333333  2011
# ...

# %%
y2_train
# Out:
# 2117    7.0
# 2014    6.5
# 2158    7.0
# 1111    6.5
# 958     6.5
#        ...
# 1648    7.0
# 1478    6.5
# 2321    6.5
# 433     6.9
# 1329    7.0
# Name: pH (standard units), Length: 1240, dtype: float64

# %%
y2_test
# Out:
# 1257    6.5
# 1029    6.5
# 1644    7.0
# 1303    7.0
# 848     7.0
#        ...
# 1944    7.5
# 8       7.2
# 448     8.1
# 731     6.5
# 1441    6.5
# Name: pH (standard units), Length: 532, dtype: float64

# %% [markdown]
# **MODEL BUILDING**

# %%
#REGRESSION
from sklearn.linear_model import LinearRegression
model2 = LinearRegression()
model2.fit(x2_train,y2_train)
# Out:
# LinearRegression()

# %%
y2_predict = model2.predict(x2_test)

# %% [markdown]
# #**EVALUATION** **REGRESSION**

# %%
from sklearn.metrics import mean_absolute_error

# %%
print("MAE 2 is ",mean_absolute_error(y2_test,y2_predict))
# Out:
# MAE 2 is  0.42723109848120877

# %%
from sklearn.metrics import mean_squared_error

# %%
print("MSE 2 is",mean_squared_error(y2_test,y2_predict))
# Out:
# MSE 2 is 0.3097918826021811

# %%
from sklearn.metrics import root_mean_squared_error

# %%
print("RMSE 2 is ",root_mean_squared_error(y2_test,y2_predict))
# Out:
# RMSE 2 is  0.5565895099641935

# %% [markdown]
# # REPRESENTATION OF MAE2 , MSE2, RMSE2

# %%
MAE2 = 0.4272
MSE2 = 0.3097
RMSE2 =0.5565

# %%
metrics = ['MAE2', 'MSE2', 'RMSE2']
values = [MAE2, MSE2, RMSE2]

# %%
plt.bar(metrics, values)
plt.xlabel('Metrics')
plt.ylabel('Error Values')
plt.title('Error Metrics for Model 2')
# Out:
# Text(0.5, 1.0, 'Error Metrics for Model 2')

# %% [markdown]
# # MODEL 2 CONCLUSION
#
# **Model 2 incorporates data cleaning techniques from Model 1, and additionally, it includes the crucial step of outlier removal. This extra step significantly enhances the model's predictive accuracy. As a result, Model 2 exhibits lower error values for MAE, MSE, and RMSE than model 1.**

# %% [markdown]
# #df3

# %%
df3
# Out:
#      Site_Id Unit_Id   Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0        Bay     NaN    1/3/1994             1.3                     11.7
# 1        Bay     NaN   1/31/1994             1.5                     12.0
# 2        Bay     NaN    2/7/1994             1.0                     10.5
# 3        Bay     NaN   2/23/1994             1.0                     10.1
# 4        Bay     NaN   2/28/1994             1.0                     12.6
# ...      ...     ...         ...             ...                      ...
# 2366     Bay     NaN  10/11/2018             1.9                      5.0
# 2367     Bay     NaN  10/24/2018             0.0                      9.0
# 2368     Bay     NaN  10/28/2018             0.9                      2.9
# 2369     Bay     NaN   11/7/2018             1.7                      NaN
# 2370     Bay     NaN  12/11/2018             0.1                      NaN
#
#       pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# ...

# %% [markdown]
# **EXPLORATORY** **DATA** **ANALYSIS**

# %%
df3.shape
# Out:
# (2371, 17)

# %%
df3.head()
# Out:
#   Site_Id Unit_Id  Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0     Bay     NaN   1/3/1994             1.3                     11.7
# 1     Bay     NaN  1/31/1994             1.5                     12.0
# 2     Bay     NaN   2/7/1994             1.0                     10.5
# 3     Bay     NaN  2/23/1994             1.0                     10.1
# 4     Bay     NaN  2/28/1994             1.0                     12.6
#
#    pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# 0                  7.3              0.40             0.40              5.9
# 1                  7.4              0.20             0.35              3.0
# 2                  7.2              0.25             0.60              5.9
# 3                  7.4              0.35             0.50             10.0
# 4                  7.2              0.20             0.40              1.6
#
#    Air Temp-Celsius  Air Temp (?F) Time (24:00) Field_Tech DateVerified  \
# ...

# %%
df3.tail()
# Out:
#      Site_Id Unit_Id   Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 2366     Bay     NaN  10/11/2018             1.9                      5.0
# 2367     Bay     NaN  10/24/2018             0.0                      9.0
# 2368     Bay     NaN  10/28/2018             0.9                      2.9
# 2369     Bay     NaN   11/7/2018             1.7                      NaN
# 2370     Bay     NaN  12/11/2018             0.1                      NaN
#
#       pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# 2366                  7.0              4.00              1.2             25.0
# 2367                  7.0              0.30              0.6             18.0
# 2368                  7.0              0.40              0.9             13.0
# 2369                  7.0              0.45              0.9             20.0
# 2370                  7.0              0.10              0.1             10.0
#
# ...

# %%
df3.iloc[100:288]
# Out:
#     Site_Id Unit_Id  Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 100     Bay     NaN   3/4/1991             1.2                    10.00
# 101     Bay     NaN  3/11/1991             0.4                    12.90
# 102     Bay     NaN  3/18/1991             NaN                     9.95
# 103     Bay     NaN  3/25/1991             0.0                     9.80
# 104     Bay     NaN   4/4/1991             1.2                    10.70
# ..      ...     ...        ...             ...                      ...
# 283     Bay     NaN  8/11/1996             3.1                      NaN
# 284     Bay     NaN  8/18/1996             3.0                     4.65
# 285     Bay     NaN   9/1/1996             2.8                     2.00
# 286     Bay     NaN  9/15/1996             3.0                     2.00
# 287     Bay     NaN  9/22/1996             3.1                     2.00
#
#      pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2371 entries, 0 to 2370
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Site_Id                  2370 non-null   object
#  1   Unit_Id                  32 non-null     object
#  2   Read_Date                2366 non-null   object
#  3   Salinity (ppt)           2241 non-null   float64
#  4   Dissolved Oxygen (mg/L)  1520 non-null   float64
#  5   pH (standard units)      2276 non-null   float64
#  6   Secchi Depth (m)         2298 non-null   float64
#  7   Water Depth (m)          2300 non-null   float64
#  8   Water Temp (?C)          2250 non-null   float64
#  9   Air Temp-Celsius         85 non-null     float64
#  10  Air Temp (?F)            2300 non-null   float64
#  11  Time (24:00)             2308 non-null   object
#  12  Field_Tech               2332 non-null   object
#  13  DateVerified             453 non-null    object
# ...

# %%
df3.columns
# Out:
# Index(['Site_Id', 'Unit_Id', 'Read_Date', 'Salinity (ppt)',
#        'Dissolved Oxygen (mg/L)', 'pH (standard units)', 'Secchi Depth (m)',
#        'Water Depth (m)', 'Water Temp (?C)', 'Air Temp-Celsius',
#        'Air Temp (?F)', 'Time (24:00)', 'Field_Tech', 'DateVerified',
#        'WhoVerified', 'AirTemp (C)', 'Year'],
#       dtype='object')

# %%
df3.describe()
# Out:
#        Salinity (ppt)  Dissolved Oxygen (mg/L)  pH (standard units)  \
# count     2241.000000              1520.000000          2276.000000
# mean         0.717068                 6.646263             7.168212
# std          1.230819                 2.506608             0.788485
# min          0.000000                 0.000000             0.300000
# 25%          0.000000                 4.800000             6.500000
# 50%          0.000000                 6.500000             7.000000
# 75%          1.000000                 8.500000             7.500000
# max          9.000000                15.100000             9.900000
#
#        Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  Air Temp-Celsius  \
# count       2298.000000      2300.000000      2250.000000         85.000000
# mean           0.524898         0.762559        18.062138         16.437647
# std            0.473663         0.621140         8.298246         11.754138
# ...

# %% [markdown]
# #DIAGRAM REPRESENTATION

# %%
summary3 = df3.describe()

# %%
summary3.T.plot(kind='bar', figsize=(10,5))
plt.title('Summary3 Statistics')
plt.ylabel('Values')
plt.xlabel('Statistics')
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# **DATACLEANING**

# %%
df3.isna()
# Out:
#       Site_Id  Unit_Id  Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0       False     True      False           False                    False
# 1       False     True      False           False                    False
# 2       False     True      False           False                    False
# 3       False     True      False           False                    False
# 4       False     True      False           False                    False
# ...       ...      ...        ...             ...                      ...
# 2366    False     True      False           False                    False
# 2367    False     True      False           False                    False
# 2368    False     True      False           False                    False
# 2369    False     True      False           False                     True
# 2370    False     True      False           False                     True
#
# ...

# %%
df3 = df3.drop(['Site_Id'],axis = 1)

# %%
df3 = df3.drop(['Unit_Id'],axis = 1)

# %%
df3 = df3.drop(['Read_Date'],axis = 1)

# %%
df3.isna().sum()
# Out:
# Salinity (ppt)              130
# Dissolved Oxygen (mg/L)     851
# pH (standard units)          95
# Secchi Depth (m)             73
# Water Depth (m)              71
# Water Temp (?C)             121
# Air Temp-Celsius           2286
# Air Temp (?F)                71
# Time (24:00)                 63
# Field_Tech                   39
# DateVerified               1918
# WhoVerified                1918
# AirTemp (C)                   0
# Year                          0
# dtype: int64

# %% [markdown]
# # Total no of records = 2371
# Salinity = 130/2371*100 =5.4
#
# Dissolved Oxygen (mg/L) = 851/2371*100 = 35.89
#
# Secchi Depth (m) = 73/2371*100 = 3.07
#
# Water Depth (m)= 71/2371*100 = 2.9
#
# Water Temp (?C) =121/2371*100 =5.1
#
# Air Temp-Celsius = 2286/2371*100 =96.4
#
# Air Temp (?F) = 71/2371*100 =2.9
#
# Time (24:00) = 63/2371*100 =2.6
#
# Field_Tech = 39/2371*100 =1.6
#
# DateVerified = 1918/2371*100 =80.89
#
# WhoVerified = 1918/2371*100 =80.89
#
# pH (standard units) = 95/2371*100 = 4
#
#
#
# MORE THAN 3% MISSING VALUE SO WE HAVE TO DEAL

# %% [markdown]
# DROPPING THE COLUMNS WHICH HAVE LESS THAN 3% AND MORE THAN 60% MISSING VALUES

# %%
df3 = df3.drop(['Water Depth (m)'],axis =1)

# %%
df3 = df3.drop(['Air Temp (?F)'],axis =1)

# %%
df3 = df3.drop(['Time (24:00)'],axis =1)

# %%
df3 = df3.drop(['DateVerified'],axis =1)

# %%
df3 = df3.drop(['WhoVerified'],axis =1)

# %%
df3 = df3.drop(['Field_Tech'],axis =1)

# %%
df3 = df3.drop(['Air Temp-Celsius'],axis =1)

# %%
flo_cols = ['Salinity (ppt)','Dissolved Oxygen (mg/L)','Secchi Depth (m)','Water Temp (?C)']

# %%
df3[flo_cols] = df3[flo_cols].fillna(df3.mode().iloc[0])

# %%
 df3 = df3.dropna(subset = ['pH (standard units)'])

# %%
df3.isna().sum()
# Out:
# Salinity (ppt)             0
# Dissolved Oxygen (mg/L)    0
# pH (standard units)        0
# Secchi Depth (m)           0
# Water Temp (?C)            0
# AirTemp (C)                0
# Year                       0
# dtype: int64

# %% [markdown]
# # LABEL ENCODING

# %% [markdown]
# NO CATEGORICAL COLUMNS
#
# HENCE ENCODING NOT NEEDED

# %% [markdown]
# **SPLITING** **X3** **AND** **Y3**

# %%
x3 = df3.iloc[:,[0,1,3,4,5,6]]

# %%
x3
# Out:
#       Salinity (ppt)  Dissolved Oxygen (mg/L)  Secchi Depth (m)  \
# 0                1.3                     11.7              0.40
# 1                1.5                     12.0              0.20
# 2                1.0                     10.5              0.25
# 3                1.0                     10.1              0.35
# 4                1.0                     12.6              0.20
# ...              ...                      ...               ...
# 2366             1.9                      5.0              4.00
# 2367             0.0                      9.0              0.30
# 2368             0.9                      2.9              0.40
# 2369             1.7                     10.0              0.45
# 2370             0.1                     10.0              0.10
#
#       Water Temp (?C)  AirTemp (C)  Year
# 0                 5.9     8.000000  1994
# 1                 3.0     2.600000  1994
# 2                 5.9     7.600000  1994
# ...

# %%
y3 = df3.iloc[:,2]

# %%
y3
# Out:
# 0       7.3
# 1       7.4
# 2       7.2
# 3       7.4
# 4       7.2
#        ...
# 2366    7.0
# 2367    7.0
# 2368    7.0
# 2369    7.0
# 2370    7.0
# Name: pH (standard units), Length: 2276, dtype: float64

# %% [markdown]
# #DATA NORMALIZATION

# %%
from sklearn import preprocessing
from sklearn.preprocessing import Normalizer

# %%
scaler = Normalizer(norm ='l1').fit(x3)

# %%
x3_norm = scaler.transform(x3)

# %%
print(x3_norm[0:7])
# Out:
# [[6.43150448e-04 5.78835403e-03 1.97892445e-04 2.91891357e-03
#   3.95784891e-03 9.86493841e-01]
#  [7.45045448e-04 5.96036358e-03 9.93393930e-05 1.49009090e-03
#   1.29141211e-03 9.90413749e-01]
#  [4.95233379e-04 5.19995048e-03 1.23808345e-04 2.92187693e-03
#   3.76377368e-03 9.87495357e-01]
#  [4.95503307e-04 5.00458341e-03 1.73426158e-04 4.95503307e-03
#   1.33785893e-03 9.88033595e-01]
#  [4.97660993e-04 6.27052852e-03 9.95321987e-05 7.96257589e-04
#   0.00000000e+00 9.92336021e-01]
#  [4.92610837e-04 4.87684729e-03 9.85221675e-05 4.77832512e-03
#   7.48768473e-03 9.82266010e-01]
#  [2.46907484e-04 5.13567566e-03 1.23453742e-04 4.83938668e-03
#   4.98753117e-03 9.84667045e-01]]

# %%
scaler2 = Normalizer(norm = 'l2').fit(x3)
x3_norm2 = scaler2.transform(x3)

# %%
print(x3_norm2[0:7])
# Out:
# [[6.51936393e-04 5.86742754e-03 2.00595813e-04 2.95878824e-03
#   4.01191626e-03 9.99970129e-01]
#  [7.52241441e-04 6.01793153e-03 1.00298859e-04 1.50448288e-03
#   1.30388516e-03 9.99979622e-01]
#  [5.01491656e-04 5.26566239e-03 1.25372914e-04 2.95880077e-03
#   3.81133659e-03 9.99974362e-01]
#  [5.01491244e-04 5.06506156e-03 1.75521935e-04 5.01491244e-03
#   1.35402636e-03 9.99973540e-01]
#  [5.01494274e-04 6.31882786e-03 1.00298855e-04 8.02390839e-04
#   0.00000000e+00 9.99979583e-01]
#  [5.01477764e-04 4.96462987e-03 1.00295553e-04 4.86433431e-03
#   7.62246202e-03 9.99946662e-01]
#  [2.50742592e-04 5.21544591e-03 1.25371296e-04 4.91455480e-03
#   5.06500035e-03 9.99961456e-01]]

# %% [markdown]
# **TRAIN** **TEST** **SPLIT**

# %%
from sklearn.model_selection import train_test_split
x3_train,x3_test,y3_train,y3_test = train_test_split(x3_norm,y3,test_size=0.3,random_state = 5)

# %%
x3_train
# Out:
# array([[ 0.00000000e+00,  4.84845873e-03,  1.93938349e-04,
#          9.21207158e-03,  7.81140573e-03,  9.77934126e-01],
#        [ 8.82223202e-04,  5.19531441e-03,  1.96049601e-04,
#          7.64593442e-03,  9.26334363e-03,  9.76817135e-01],
#        [ 9.68509974e-04,  4.84254987e-03,  1.21063747e-04,
#          1.30748847e-02, -8.60897755e-03,  9.72384014e-01],
#        ...,
#        [ 0.00000000e+00,  4.83447302e-03,  3.38413111e-04,
#          1.25696298e-02,  1.10118552e-02,  9.71245629e-01],
#        [ 0.00000000e+00,  2.58042877e-03,  1.94749341e-04,
#          9.25059372e-03,  8.38504109e-03,  9.79589187e-01],
#        [ 0.00000000e+00,  3.03544565e-03,  1.92726708e-04,
#          1.25272360e-02,  1.33837992e-02,  9.70860792e-01]])

# %%
x3_test
# Out:
# array([[ 0.00000000e+00,  4.84423106e-03,  5.81307727e-04,
#          1.30794239e-02,  7.80459448e-03,  9.73690443e-01],
#        [ 9.72158462e-04,  4.86079231e-03,  2.43039615e-04,
#          1.02076638e-02,  1.10718047e-02,  9.72644541e-01],
#        [ 0.00000000e+00,  4.84172925e-03,  2.90503755e-04,
#          1.54935336e-02, -8.60751867e-03,  9.70766715e-01],
#        ...,
#        [ 0.00000000e+00,  1.97976243e-03,  1.44860666e-04,
#          1.30374599e-02,  9.92563819e-03,  9.74912279e-01],
#        [ 1.84921591e-03,  3.30912320e-03,  1.58156624e-04,
#          1.26525299e-02,  1.31391657e-02,  9.68891809e-01],
#        [ 0.00000000e+00,  2.37130406e-03,  4.74260812e-05,
#          3.50953001e-02,  1.15930421e-02,  9.50892928e-01]])

# %%
y3_train
# Out:
# 2152    6.5
# 215     8.4
# 1335    8.5
# 1626    6.5
# 1170    7.0
#        ...
# 1072    7.0
# 2209    6.5
# 1480    6.5
# 1795    8.0
# 2349    9.0
# Name: pH (standard units), Length: 1593, dtype: float64

# %%
y3_test
# Out:
# 1599    6.0
# 517     7.8
# 990     6.5
# 2313    9.0
# 1176    7.0
#        ...
# 151     7.5
# 2091    7.5
# 2286    7.0
# 112     7.5
# 1038    6.5
# Name: pH (standard units), Length: 683, dtype: float64

# %% [markdown]
# **MODEL BUILDING**

# %%
#REGRESSION
from sklearn.linear_model import LinearRegression
model3 = LinearRegression()
model3.fit(x3_train,y3_train)
# Out:
# LinearRegression()

# %%
y3_predict = model3.predict(x3_test)

# %% [markdown]
# EVALUATION REGRESSION

# %%
from sklearn.metrics import mean_absolute_error

# %%
print("MAE 3 is ",mean_absolute_error(y3_test,y3_predict))
# Out:
# MAE 3 is  0.5610311162513686

# %%
from sklearn.metrics import mean_squared_error

# %%
print("MSE 3 is",mean_squared_error(y3_test,y3_predict))
# Out:
# MSE 3 is 0.6043421380580001

# %%
from sklearn.metrics import root_mean_squared_error

# %%
print("RMSE 3 is ",root_mean_squared_error(y3_test,y3_predict))
# Out:
# RMSE 3 is  0.7773944546097561

# %% [markdown]
# # REPRESENTATION OF MAE3 ,MSE3, RMSE3

# %%
MAE3 =0.5610
MSE3 =0.6043
RMSE3=0.7773

# %%
metrics = ['MAE3', 'MSE3', 'RMSE3']
values = [MAE3, MSE3, RMSE3]

# %%
plt.bar(metrics, values)
plt.xlabel('Metrics')
plt.ylabel('Error Values')
plt.title('Error Metrics for Model 3')
# Out:
# Text(0.5, 1.0, 'Error Metrics for Model 3')

# %% [markdown]
# #MODEL 3 CONCLUSION
#
# **Model 3 incorporates the same data cleaning steps as Model 1 In addition Model 3 introduces data normalization using the Normalizer from sklearn.preprocessing. The normalization is applied to the input features (x3) with both 'l1' and 'l2' norms.**
#
# **However, despite the added normalization step, Model 3 does not show any significant improvement in performance compared to Model 1. The error values for MAE, MSE, and RMSE remain the same as in Model 1, indicating that normalization did not have a positive impact on the model's predictive accuracy in this particular case.**
#
#
# **Therefore, the conclusion for Model 3 is that although data normalization is a valuable technique in many machine learning scenarios, it did not lead to improved performance in this specific case.**

# %% [markdown]
# #df4

# %%
df4
# Out:
#      Site_Id Unit_Id   Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0        Bay     NaN    1/3/1994             1.3                     11.7
# 1        Bay     NaN   1/31/1994             1.5                     12.0
# 2        Bay     NaN    2/7/1994             1.0                     10.5
# 3        Bay     NaN   2/23/1994             1.0                     10.1
# 4        Bay     NaN   2/28/1994             1.0                     12.6
# ...      ...     ...         ...             ...                      ...
# 2366     Bay     NaN  10/11/2018             1.9                      5.0
# 2367     Bay     NaN  10/24/2018             0.0                      9.0
# 2368     Bay     NaN  10/28/2018             0.9                      2.9
# 2369     Bay     NaN   11/7/2018             1.7                      NaN
# 2370     Bay     NaN  12/11/2018             0.1                      NaN
#
#       pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# ...

# %% [markdown]
# **EXPLORATORY** **DATA** **ANALYSIS**

# %%
df4.shape
# Out:
# (2371, 17)

# %%
df4.head()
# Out:
#   Site_Id Unit_Id  Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0     Bay     NaN   1/3/1994             1.3                     11.7
# 1     Bay     NaN  1/31/1994             1.5                     12.0
# 2     Bay     NaN   2/7/1994             1.0                     10.5
# 3     Bay     NaN  2/23/1994             1.0                     10.1
# 4     Bay     NaN  2/28/1994             1.0                     12.6
#
#    pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# 0                  7.3              0.40             0.40              5.9
# 1                  7.4              0.20             0.35              3.0
# 2                  7.2              0.25             0.60              5.9
# 3                  7.4              0.35             0.50             10.0
# 4                  7.2              0.20             0.40              1.6
#
#    Air Temp-Celsius  Air Temp (?F) Time (24:00) Field_Tech DateVerified  \
# ...

# %%
df4.tail()
# Out:
#      Site_Id Unit_Id   Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 2366     Bay     NaN  10/11/2018             1.9                      5.0
# 2367     Bay     NaN  10/24/2018             0.0                      9.0
# 2368     Bay     NaN  10/28/2018             0.9                      2.9
# 2369     Bay     NaN   11/7/2018             1.7                      NaN
# 2370     Bay     NaN  12/11/2018             0.1                      NaN
#
#       pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# 2366                  7.0              4.00              1.2             25.0
# 2367                  7.0              0.30              0.6             18.0
# 2368                  7.0              0.40              0.9             13.0
# 2369                  7.0              0.45              0.9             20.0
# 2370                  7.0              0.10              0.1             10.0
#
# ...

# %%
df4.iloc[100:400]
# Out:
#     Site_Id Unit_Id  Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 100     Bay     NaN   3/4/1991             1.2                    10.00
# 101     Bay     NaN  3/11/1991             0.4                    12.90
# 102     Bay     NaN  3/18/1991             NaN                     9.95
# 103     Bay     NaN  3/25/1991             0.0                     9.80
# 104     Bay     NaN   4/4/1991             1.2                    10.70
# ..      ...     ...        ...             ...                      ...
# 395       A     NaN  5/15/2000             1.0                     6.40
# 396       A     NaN  5/30/2000             0.5                      NaN
# 397       A     NaN  6/13/2000             1.0                      NaN
# 398       A     NaN  6/26/2000             1.0                     5.50
# 399       A     NaN  7/11/2000             0.8                      NaN
#
#      pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2371 entries, 0 to 2370
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Site_Id                  2370 non-null   object
#  1   Unit_Id                  32 non-null     object
#  2   Read_Date                2366 non-null   object
#  3   Salinity (ppt)           2241 non-null   float64
#  4   Dissolved Oxygen (mg/L)  1520 non-null   float64
#  5   pH (standard units)      2276 non-null   float64
#  6   Secchi Depth (m)         2298 non-null   float64
#  7   Water Depth (m)          2300 non-null   float64
#  8   Water Temp (?C)          2250 non-null   float64
#  9   Air Temp-Celsius         85 non-null     float64
#  10  Air Temp (?F)            2300 non-null   float64
#  11  Time (24:00)             2308 non-null   object
#  12  Field_Tech               2332 non-null   object
#  13  DateVerified             453 non-null    object
# ...

# %%
df4.columns
# Out:
# Index(['Site_Id', 'Unit_Id', 'Read_Date', 'Salinity (ppt)',
#        'Dissolved Oxygen (mg/L)', 'pH (standard units)', 'Secchi Depth (m)',
#        'Water Depth (m)', 'Water Temp (?C)', 'Air Temp-Celsius',
#        'Air Temp (?F)', 'Time (24:00)', 'Field_Tech', 'DateVerified',
#        'WhoVerified', 'AirTemp (C)', 'Year'],
#       dtype='object')

# %%
df4.describe()
# Out:
#        Salinity (ppt)  Dissolved Oxygen (mg/L)  pH (standard units)  \
# count     2241.000000              1520.000000          2276.000000
# mean         0.717068                 6.646263             7.168212
# std          1.230819                 2.506608             0.788485
# min          0.000000                 0.000000             0.300000
# 25%          0.000000                 4.800000             6.500000
# 50%          0.000000                 6.500000             7.000000
# 75%          1.000000                 8.500000             7.500000
# max          9.000000                15.100000             9.900000
#
#        Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  Air Temp-Celsius  \
# count       2298.000000      2300.000000      2250.000000         85.000000
# mean           0.524898         0.762559        18.062138         16.437647
# std            0.473663         0.621140         8.298246         11.754138
# ...

# %% [markdown]
# **DIAGRAM** **REPRESENTATION**

# %%
summary4 = df4.describe()

# %%
summary4.T.plot(kind='bar', figsize=(10,5))
plt.title('Summary4 Statistics')
plt.ylabel('Values')
plt.xlabel('Statistics')
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# **DATACLEANING**

# %%
df4.isna()
# Out:
#       Site_Id  Unit_Id  Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0       False     True      False           False                    False
# 1       False     True      False           False                    False
# 2       False     True      False           False                    False
# 3       False     True      False           False                    False
# 4       False     True      False           False                    False
# ...       ...      ...        ...             ...                      ...
# 2366    False     True      False           False                    False
# 2367    False     True      False           False                    False
# 2368    False     True      False           False                    False
# 2369    False     True      False           False                     True
# 2370    False     True      False           False                     True
#
# ...

# %%
df4 = df4.drop(['Site_Id'],axis = 1)

# %%
df4 = df4.drop(['Unit_Id'],axis = 1)

# %%
df4 = df4.drop(['Read_Date'],axis = 1)

# %%
df4.isna().sum()
# Out:
# Salinity (ppt)              130
# Dissolved Oxygen (mg/L)     851
# pH (standard units)          95
# Secchi Depth (m)             73
# Water Depth (m)              71
# Water Temp (?C)             121
# Air Temp-Celsius           2286
# Air Temp (?F)                71
# Time (24:00)                 63
# Field_Tech                   39
# DateVerified               1918
# WhoVerified                1918
# AirTemp (C)                   0
# Year                          0
# dtype: int64

# %% [markdown]
# #Total no of records = 2371
# Salinity = 130/2371*100 =5.4
#
# Dissolved Oxygen (mg/L) = 851/2371*100 = 35.89
#
# Secchi Depth (m) = 73/2371*100 = 3.07
#
# Water Depth (m)= 71/2371*100 = 2.9
#
# Water Temp (?C) =121/2371*100 =5.1
#
# Air Temp-Celsius = 2286/2371*100 =96.4
#
# Air Temp (?F) = 71/2371*100 =2.9
#
# Time (24:00) = 63/2371*100 =2.6
#
# Field_Tech = 39/2371*100 =1.6
#
# DateVerified = 1918/2371*100 =80.89
#
# WhoVerified = 1918/2371*100 =80.89
#
# pH (standard units) = 95/2371*100 = 4
#
#
#
# MORE THAN 3% MISSING VALUE SO WE HAVE TO DEAL

# %% [markdown]
# DROPPING THE COLUMNS WHICH HAVE LESS THAN 3% AND MORE THAN 60% MISSING VALUES

# %%
df4 = df4.drop(['Water Depth (m)'],axis =1)

# %%
df4 = df4.drop(['Air Temp (?F)'],axis =1)

# %%
df4 = df4.drop(['Time (24:00)'],axis =1)

# %%
df4 = df4.drop(['DateVerified'],axis =1)

# %%
df4 = df4.drop(['WhoVerified'],axis =1)

# %%
df4 = df4.drop(['Field_Tech'],axis =1)

# %%
df4 = df4.drop(['Air Temp-Celsius'],axis =1)

# %%
flo_cols = ['Salinity (ppt)','Dissolved Oxygen (mg/L)','Secchi Depth (m)','Water Temp (?C)']

# %%
df4[flo_cols] = df4[flo_cols].fillna(df1.mode().iloc[0])

# %%
 df4 = df4.dropna(subset = ['pH (standard units)'])

# %%
df4.isna().sum()
# Out:
# Salinity (ppt)             0
# Dissolved Oxygen (mg/L)    0
# pH (standard units)        0
# Secchi Depth (m)           0
# Water Temp (?C)            0
# AirTemp (C)                0
# Year                       0
# dtype: int64

# %% [markdown]
# #LABELENCODING

# %% [markdown]
# NO CATEGORICAL COLUMNS
#
# HENCE ENCODING NOT NEEEDED

# %% [markdown]
# **SPLITING** **X4** **AND** **Y4**

# %%
x4 = df4.iloc[:,[0,1,3,4,5,6]]

# %%
x4
# Out:
#       Salinity (ppt)  Dissolved Oxygen (mg/L)  Secchi Depth (m)  \
# 0                1.3                     11.7              0.40
# 1                1.5                     12.0              0.20
# 2                1.0                     10.5              0.25
# 3                1.0                     10.1              0.35
# 4                1.0                     12.6              0.20
# ...              ...                      ...               ...
# 2366             1.9                      5.0              4.00
# 2367             0.0                      9.0              0.30
# 2368             0.9                      2.9              0.40
# 2369             1.7                     10.0              0.45
# 2370             0.1                     10.0              0.10
#
#       Water Temp (?C)  AirTemp (C)  Year
# 0                 5.9     8.000000  1994
# 1                 3.0     2.600000  1994
# 2                 5.9     7.600000  1994
# ...

# %%
y4 = df4.iloc[:,2]

# %%
y4
# Out:
# 0       7.3
# 1       7.4
# 2       7.2
# 3       7.4
# 4       7.2
#        ...
# 2366    7.0
# 2367    7.0
# 2368    7.0
# 2369    7.0
# 2370    7.0
# Name: pH (standard units), Length: 2276, dtype: float64

# %% [markdown]
# #DATA STANDARDAIZATION

# %%
from sklearn.preprocessing import StandardScaler

# %%
std_datset = StandardScaler()

# %%
x4_standard = std_datset.fit_transform(x4)

# %%
x4_standard
# Out:
# array([[ 0.50888043,  1.49590945, -0.25875743, -1.49717292, -0.76619932,
#         -1.42099778],
#        [ 0.67380327,  1.61271335, -0.6822438 , -1.84420708, -1.29604438,
#         -1.42099778],
#        [ 0.26149617,  1.02869381, -0.57637221, -1.49717292, -0.8054471 ,
#         -1.42099778],
#        ...,
#        [ 0.17903475, -1.93033856, -0.25875743, -0.64753755, -0.62447122,
#          1.39808346],
#        [ 0.83872611,  0.83402063, -0.15288584,  0.19013112,  0.24770171,
#          1.39808346],
#        [-0.4806566 ,  0.83402063, -0.89398698, -1.00653841, -1.00604688,
#          1.39808346]])

# %% [markdown]
# **TRAIN** **TEST** **SPLIT**

# %%
from sklearn.model_selection import train_test_split
x4_train,x4_test,y4_train,y4_test = train_test_split(x4_standard,y4,test_size=0.3,random_state = 5)

# %%
x4_train
# Out:
# array([[-0.56311802,  0.83402063, -0.25875743,  0.07046417,  0.02965848,
#          1.28062174],
#        [ 0.92118752,  1.06762844, -0.25875743, -0.33640347,  0.30330273,
#         -1.5384595 ],
#        [ 1.08611036,  0.83402063, -0.57637221,  1.0277998 , -3.29550082,
#          0.22346627],
#        ...,
#        [-0.56311802,  0.83402063,  0.37647213,  0.90813285,  0.68378818,
#          0.34092799],
#        [-0.56311802, -0.99590729, -0.25875743,  0.07046417,  0.13868009,
#          0.69331315],
#        [-0.56311802, -0.60656092, -0.25875743,  0.90813285,  1.17438545,
#          1.0456983 ]])

# %%
x4_test
# Out:
# array([[-0.56311802,  0.83402063,  1.43518805,  1.0277998 ,  0.02965848,
#          0.45838971],
#        [ 1.08611036,  0.83402063, -0.04701424,  0.30979808,  0.68378818,
#         -0.59876575],
#        [-0.56311802,  0.83402063,  0.16472894,  1.62613457, -3.29550082,
#         -0.12891888],
#        ...,
#        [-0.56311802, -1.46312292, -0.47050061,  1.0277998 ,  0.46574494,
#          1.51554517],
#        [ 2.5704159 , -0.41188774, -0.41756482,  0.90813285,  1.09807032,
#         -1.77338293],
#        [-0.56311802, -1.1127112 , -0.89398698,  6.65214661,  0.8473206 ,
#         -0.12891888]])

# %%
y4_train
# Out:
# 2152    6.5
# 215     8.4
# 1335    8.5
# 1626    6.5
# 1170    7.0
#        ...
# 1072    7.0
# 2209    6.5
# 1480    6.5
# 1795    8.0
# 2349    9.0
# Name: pH (standard units), Length: 1593, dtype: float64

# %%
y4_test
# Out:
# 1599    6.0
# 517     7.8
# 990     6.5
# 2313    9.0
# 1176    7.0
#        ...
# 151     7.5
# 2091    7.5
# 2286    7.0
# 112     7.5
# 1038    6.5
# Name: pH (standard units), Length: 683, dtype: float64

# %% [markdown]
# **MODEL** **BUILDING**

# %%
#REGRESSION
from sklearn.linear_model import LinearRegression
model4 = LinearRegression()
model4.fit(x4_train,y4_train)
# Out:
# LinearRegression()

# %%
y4_predict = model4.predict(x4_test)

# %% [markdown]
# **EVALUATION** **REGRESSION**

# %%
from sklearn.metrics import mean_absolute_error

# %%
print("MAE 4 is ",mean_absolute_error(y4_test,y4_predict))
# Out:
# MAE 4 is  0.5443304142515786

# %%
from sklearn.metrics import mean_squared_error

# %%
print("MSE 4 is",mean_squared_error(y4_test,y4_predict))
# Out:
# MSE 4 is 0.5827638762364754

# %%
from sklearn.metrics import root_mean_squared_error

# %%
print("RMSE 4 is ",root_mean_squared_error(y4_test,y4_predict))
# Out:
# RMSE 4 is  0.7633897276204831

# %% [markdown]
# #REPRESENTATION OF MAE4,MSE4,RMSE4

# %%
MAE4 =0.5443
MSE4 =0.5827
RMSE4=0.7633

# %%
metrics = ['MAE4', 'MSE4', 'RMSE4']
values = [MAE4, MSE4, RMSE4]

# %%
plt.bar(metrics, values)
plt.xlabel('Metrics')
plt.ylabel('Error Values')
plt.title('Error Metrics for Model 4')
# Out:
# Text(0.5, 1.0, 'Error Metrics for Model 4')

# %% [markdown]
# # MODEL 4 CONCLUSION
#
# **Model 4, similar to Models 1 and 3, replicates the data cleaning procedures from Model 1. Additionally, it introduces data standardization and scaling using techniques like StandardScaler from sklearn.preprocessing**
#
# **However, despite these standardization , Model 4 does not demonstrate any substantial improvement in performance compared to Model 1. The error values for MAE, MSE, and RMSE remain consistent with those of Model 1.**
#
#  **Therefore, the conclusion for Model 4 is that while standardization is valuable technique for many machine learning tasks, their application did not yield improved results in this particular scenario.**

# %% [markdown]
# ## COMPARISION OF MODEL 1 , MODEL 2 ,MODEL 3, MODEL 4

# %%
metrics = ['MAE', 'MSE', 'RMSE']
model1_values = [0.5443, 0.5827, 0.7633]
model2_values = [0.4272, 0.3097, 0.5565]
model3_values = [0.5610, 0.6043, 0.7773]
model4_values = [0.5443, 0.5827, 0.7633]

# %%
# Create a bar chart to compare the metrics
x = np.arange(len(metrics))  # the label locations
width = 0.2  # the width of the bars

# %%
fig, ax = plt.subplots()
res1 = ax.bar(x - 1.5*width, model1_values, width, label='Model 1')
res2 = ax.bar(x - 0.5*width, model2_values, width, label='Model 2')
res3 = ax.bar(x + 0.5*width, model3_values, width, label='Model 3')
res4 = ax.bar(x + 1.5*width, model4_values, width, label='Model 4')
ax.legend()

# %% [markdown]
# # **Overall conclusion**
#
# # **Based on the bar plot comparison, we can conclude**
#
# # **Model 2 appears to be the best-performing model due to its lower error values for MAE, MSE, and RMSE.**
#
# # **Models 1, 3, and 4 seem to have comparable performance, with no significant difference in their prediction errors.**
